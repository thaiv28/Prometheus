# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from prometheus.regression import fit_lore_model

# %%
for region in ['NA LCS', 'EU LCS', 'LPL', 'LCK']:
    fit_lore_model(region=region, year=2018, evaluate=True)
# Out:
# Evaluating model for region=NA LCS, year=2018
# Model weights: [ 0.18616334 -0.10175248  0.25387331  0.034028    0.05615298], Intercept: 0.4840425531914893
# Accuracy: 0.989
# Evaluating model for region=EU LCS, year=2018
# Model weights: [ 0.11938652 -0.07799139  0.32731655  0.05525628  0.01103164], Intercept: 0.49056603773584895
# Accuracy: 0.946
# Evaluating model for region=LPL, year=2018
# Model weights: [ 0.09464358 -0.06479607  0.34922326  0.06157391  0.02388528], Intercept: 0.49092741935483863
# Accuracy: 0.976
# Evaluating model for region=LCK, year=2018
# Model weights: [ 0.09013292 -0.06739285  0.34659247  0.05322876  0.02763835], Intercept: 0.4947916666666665
# Accuracy: 0.938
